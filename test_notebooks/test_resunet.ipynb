# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))
import importlib
import src.dataset_resunet as dataset_resunet

importlib.reload(dataset_resunet)
print(dir(dataset_resunet))
# Out:
# ['Dataset', 'DownscaleDatasetResUnet', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'np', 'torch', 'xr']

# %%
from src.dataset_resunet import DownscaleDatasetResUnet

train_path = "../.data/downscaling_splits/train_norm.nc"
val_path = "../.data/downscaling_splits/val_norm.nc"
test_path = "../.data/downscaling_splits/test_norm.nc"
topo_path = "../.data/ETOPO2/topography_features_on_gridmet_masked_norm.nc"

ds = DownscaleDatasetResUnet(train_path, topo_path)
x, y, mask = ds[0]

print(x.shape)
print(y.shape)
print(mask.shape)
print(x.dtype, y.dtype, mask.dtype)
# Out:
# torch.Size([2, 240, 311])
# torch.Size([1, 240, 311])
# torch.Size([1, 240, 311])
# torch.float32 torch.float32 torch.float32

# %%
from src.dataset_resunet import DownscaleDatasetResUnet

train_path = "../.data/downscaling_splits/train_norm.nc"
topo_path = "../.data/ETOPO2/topography_features_on_gridmet_masked_norm.nc"

ds = DownscaleDatasetResUnet(train_path, topo_path)
x, y, mask = ds[0]

print(x.shape)
print(y.shape)
print(mask.shape)
print(x.dtype, y.dtype, mask.dtype)
# Out:
# torch.Size([2, 240, 311])
# torch.Size([1, 240, 311])
# torch.Size([1, 240, 311])
# torch.float32 torch.float32 torch.float32

# %%
import torch
from src.model_resunet import ResUNetDownscale

model = ResUNetDownscale(in_channels=2, out_channels=1)
x = torch.randn(4, 2, 160, 160)
y = model(x)
print(y.shape)   # should be [4, 1, 160, 160]
# Out:
# torch.Size([4, 1, 160, 160])
