# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.dataset_x_d2m_elev import DownscaleDatasetXD2MElev

# %%
ds = DownscaleDatasetXD2MElev(
    base_nc_path="../.data/downscaling_splits/train_norm.nc",
    extra_nc_path="../.data/downscaling_splits_extra/train_extra_norm.nc",
    topo_nc_path="../.data/ETOPO2/topography_features_on_gridmet_masked_norm.nc",
)

x, y, mask = ds[0]
print("x shape:", x.shape)
print("y shape:", y.shape)
print("mask shape:", mask.shape)
# Out:
# x shape: torch.Size([3, 240, 311])
# y shape: torch.Size([1, 240, 311])
# mask shape: torch.Size([1, 240, 311])
