# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
from src.dataset import DownscaleDataset
from src.model_transformer import UNetTransformerDownscale
import torch

ds = DownscaleDataset(
    "../.data/downscaling_splits/train_norm.nc",
    "../.data/ETOPO2/topography_features_on_gridmet_masked_norm.nc",
)
x, y, mask = ds[0]
print(x.shape, y.shape, mask.shape)

model = UNetTransformerDownscale(in_channels=2, out_channels=1)
out = model(x.unsqueeze(0))
print(out.shape)
# Out:
# torch.Size([2, 240, 311]) torch.Size([1, 240, 311]) torch.Size([1, 240, 311])
# /opt/anaconda3/envs/csci1470/lib/python3.11/site-packages/torch/nn/modules/transformer.py:392: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# torch.Size([1, 1, 240, 311])
